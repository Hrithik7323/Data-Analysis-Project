# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("hindi_movies_data.csv")
dataset
#dataset.head()
# Out:
#      Movie ID            Title      Genre Release Date               Director  \
# 0           1        Pathaan 2     Action   2023-02-22  Sanjay Leela Bhansali
# 1           2         Raid 2 3  Adventure   2024-09-02        Rajkumar Hirani
# 2           3         Jawaan 5   Thriller   2024-09-15         Anurag Kashyap
# 3           4         Animal 1     Comedy   2024-04-28            Karan Johar
# 4           5         Animal 2  Adventure   2023-09-19        Rajkumar Hirani
# ..        ...              ...        ...          ...                    ...
# 195       196         Animal 3    Romance   2023-08-19        Siddharth Anand
# 196       197         Raid 2 2     Horror   2023-05-10           Rohit Shetty
# 197       198  Singham Again 3  Adventure   2024-03-28  Sanjay Leela Bhansali
# 198       199       Pushpa 2 4  Adventure   2023-06-06        Siddharth Anand
# 199       200         Animal 4   Thriller   2023-10-06        Rajkumar Hirani
#
# ...

# %%
print(dataset.describe())
# Out:
#          Movie ID  IMDB Rating  Box Office Revenue (Crores)
# count  200.000000   200.000000                   200.000000
# mean   100.500000     7.294000                   249.953050
# std     57.879185     1.325082                   148.624141
# min      1.000000     5.000000                    13.080000
# 25%     50.750000     6.100000                   125.055000
# 50%    100.500000     7.200000                   248.675000
# 75%    150.250000     8.500000                   390.460000
# max    200.000000     9.500000                   499.910000

# %%
# We can also see the number of unique users and items in the dataset
print(dataset.nunique())
# Out:
# Movie ID                       200
# Title                           80
# Genre                            8
# Month                           12
# Year                             2
# Release Date                   184
# Director                        10
# Lead Actor/Actress              15
# IMDB Rating                     46
# Box Office Revenue (Crores)    199
# Production Company              10
# Country                          1
# dtype: int64

# %%
# check for missing values(Checking sum of Null Values)

print(dataset.isnull().sum())
# Out:
# Movie ID                       0
# Title                          0
# Genre                          0
# Month                          0
# Year                           0
# Release Date                   0
# Director                       0
# Lead Actor/Actress             0
# IMDB Rating                    0
# Box Office Revenue (Crores)    0
# Production Company             0
# Country                        0
# dtype: int64

# %%
dataset.describe()
# Out:
#          Movie ID  IMDB Rating  Box Office Revenue (Crores)
# count  200.000000   200.000000                   200.000000
# mean   100.500000     7.294000                   249.953050
# std     57.879185     1.325082                   148.624141
# min      1.000000     5.000000                    13.080000
# 25%     50.750000     6.100000                   125.055000
# 50%    100.500000     7.200000                   248.675000
# 75%    150.250000     8.500000                   390.460000
# max    200.000000     9.500000                   499.910000

# %% [markdown]
# Finding Answers with the Data Using Visualizations

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Finding Answers with the Data Using Visualizations

# %% [markdown]
# 1. What was the Lead Actor/Actress of Title

# %%
dataset.groupby('Lead Actor/Actress')['IMDB Rating'].count().plot(kind='bar', title=' Top Lead Actor/Actress of IMDB Rating')
# Show the graph
plt.xlabel("Number of Lead Actor/Actress")
plt.ylabel("Number of IMDB Rating")  # Fixed the ylabel to be more clear
plt.xticks(rotation=90)  # Added rotation for better readability
plt.tight_layout()  # Added to prevent label cutoff
plt.show()

# %% [markdown]
# 2. Which was the best month for Movies IMDB Rating between 2023 to 2024?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
dataset = pd.read_csv("hindi_movies_data.csv")

# Filtering data for 2023-2024
dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

# Grouping data by month and IMDB Rating
dataset_2023_2024.groupby('Month')['IMDB Rating'].count().plot(kind='bar', color='skyblue', edgecolor='black')

# Enhanching the plot
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Movies', fontsize=12)
plt.title('Best Month For Movies (2023-2024)', fontsize=14)
plt.xticks(rotation=0)   # Keeps month lables straight
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Adds a grid for better readability
plt.show()

# %% [markdown]
# 3 Which Director the higest Box Office Revenue (Crores) Year(2023-2024)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("hindi_movies_data.csv")

dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

# Grouping data by Director and Box office 
top_Director = dataset_2023_2024.groupby('Director')['Box Office Revenue (Crores)'].sum().sort_values(ascending=False).head(10)

# Plot the top 10 Director
top_Director.plot(kind='bar', color='skyblue', edgecolor='black')

plt.xlabel('Director', fontsize=12)
plt.ylabel('Number of Box Office Revenue (Crores)', fontsize=12)
plt.title('Director Wise Top 10 Box Office Revenue (Crores) (2023-2024)', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 4 What Movies Collection  the most in the two Year 2023 & 2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("hindi_movies_data.csv")

# Creating a Grid of Subplots (2*2 layout)
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# plt.subplots(2, 2) → Creates a 2-row, 2-column grid for subplots.
# figsize=(12, 10) → Defines the size of the entire figure.

# axs is an array of subplots where:
# axs[0,0] = Top left
# axs[0,1] = Top right
# axs[1,0] = Bottom left
# axs[1,1] = Bottom right (unused in this case)

top_MoviesCollection_2023 = dataset[dataset['Year'] == 2023].groupby('Lead Actor/Actress')['Box Office Revenue (Crores)']
.count().sort_values(ascending=False).head(10)

# x = top_MoviesCollection_2023.index → top_MoviesCollection_2023 (X-axis).
# y = top_MoviesCollection_2023.index → top_MoviesCollection_2023 (Y-axis).
axs[0, 0].bar(top_MoviesCollection_2023.index, top_MoviesCollection_2023)
axs[0, 0].set_title('Top Movies Collection in 2023')
axs[0, 0].tick_params(axis='x', rotation=45)

top_MoviesCollection_2024 = dataset[dataset['Year'] == 2024].groupby('Lead Actor/Actress')['Box Office Revenue (Crores)']
.count().sort_values(ascending=False).head(10)
axs[0, 1].bar(top_MoviesCollection_2024.index, top_MoviesCollection_2024)
axs[0, 1].set_title('Top Movies Collection in 2024')
axs[0, 1].tick_params(axis='x', rotation=45)

axs[1, 1].axis('off')


plt.tight_layout()
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
5 Which Movies by Production Company the most Box Office Revenue (Crores) between 2023 to 2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("hindi_movies_data.csv")

dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

(dataset_2023_2024.groupby('Production Company')['Box Office Revenue (Crores)'].sum().sort_values(ascending=False).head(10)
  .plot(kind='bar',title='Top 10 Most Movies Production Company 2023 to 2024'))

plt.tight_layout()
plt.show()

# %% [markdown]
# 6 Which Movies by Production Company the Least Box Office Revenue (Crores) between 2023 to 2024?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("hindi_movies_data.csv")

dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

(dataset_2023_2024.groupby('Production Company')['Box Office Revenue (Crores)'].sum().sort_values(ascending=True).head(10)
  .plot(kind='bar',title='Top 10 Least Movies Production Company 2023 to 2024'))

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Genre Distribution?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("hindi_movies_data.csv")

sns.countplot(x='Genre', data=dataset)

plt.show()

# %% [markdown]
# 8.  what is the Best Director IMDB Rating 2023 to 2024?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("hindi_movies_data.csv")

dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

(dataset_2023_2024.groupby('Director')['IMDB Rating'].mean().sort_values(ascending=False).head(10)
  .plot(kind='bar',title='Best Director IMDB Rating 2023 to 2024'))

plt.show()

# %% [markdown]
# 9. Top 5 Production Company Box Office Revenue (Crores) percentage?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("hindi_movies_data.csv")

dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

(dataset_2023_2024.groupby('Production Company')['Box Office Revenue (Crores)'].sum().sort_values(ascending=False).head(5)
  .plot(kind='pie', autopct='%1.1f%%', title='Top 5 Production Company Box Office Revenue percentage'))

plt.show()

# %% [markdown]
# 10. Director wise IMDB Rating percentage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("hindi_movies_data.csv")

dataset_2023_2024 = dataset[(dataset['Year'] >= 2023) & (dataset['Year'] <= 2024)]

(dataset_2023_2024.groupby('Director')['IMDB Rating'].sum().sort_values(ascending=False).head(5)
  .plot(kind='pie', autopct='%1.1f%%', title='Top 5 Director wise IMDB Rating percentage'))

plt.show()
